# %% [markdown]
# ## OPENCV
# ##### 25/05/2022

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %% [markdown]
# ### Read the image

# %%
import cv2 as cv

# %%
image=cv.imread(r'colorfull.jpg')
cv.imshow('big data',image)
cv.waitKey(0)
# Out:
# -1

# %%
import matplotlib.pyplot as plt
image=cv.imread(r'colorfull.jpg')
plt.imshow(image)

# %% [markdown]
# #### Write Image

# %%
import cv2 as cv
image=cv.imread(r'colorfull.jpg')
cv.imwrite(r'colorfullmunna.jpg',image)
cv.imwrite(r'colorfullmunna1.jpg',image)
cv.imshow('big data',image)
cv.waitKey(0)
# Out:
# -1

# %% [markdown]
# ### Practice

# %%
img=cv.imread(r'puppy.jpg')
cv.imshow('Figure',img)
cv.waitKey(0)
# Out:
# -1

# %%
import matplotlib.pyplot as plt
img=cv.imread(r'puppy.jpg')
plt.imshow(img)

# %%
image=cv.imread(r'puppy.jpg')
image2=cv.imread(r'bird.webp')
cv.imwrite(r'puppy1.jpg',image)
cv.imwrite(r'puppy2.jpg',image)
cv.imwrite(r'puppy3.jpg',image)
cv.imshow('Figure2',image)
cv.imshow('Figure3',image2)
cv.waitKey(0)
# Out:
# -1

# %% [markdown]
# Q. How computers understand image an in which form?
#
# Ans. Computers use Machine Learning Algorithms, Dots, Edge Detection and Grids to understand the images.
# Computer understand images in the form of Pixels.

# %% [markdown]
# 26/05/2022

# %%
import cv2 as cv
import numpy as np 
pic=cv.imread(r"puppy.jpg")
re=cv.resize(pic,(500,500)) #resize the image
rotate=cv.rotate(pic,cv.ROTATE_90_CLOCKWISE) #Rotate the Image ate 90 clockwise
rotate180=cv.rotate(pic,cv.ROTATE_180) #Rotate the image at 180 degree
cv.imshow('180 degree rotated image',rotate180)
cv.imshow('90 degree clockwise rotated image',rotate)
cv.imshow('Resized Image',re)
rgb=cv.cvtColor(pic,cv.COLOR_BGR2RGB)
gray=cv.cvtColor(pic,cv.COLOR_BGR2GRAY)
cv.imshow('Original Image',pic)
cv.imshow('BGR 2 RGB converted',rgb)
cv.imshow('BGR 2 GRAY converted',gray)
cv.waitKey(0)
# Out:
# -1

# %%
import cv2 as cv
import numpy as np 
pic=cv.imread(r"puppy.jpg")
pic
#type(pic)
#np.shape(pic)
#pic.shape
# Out:
# array([[[ 56,  95,  74],
#         [ 57,  96,  75],
#         [ 57,  96,  75],
#         ...,
#         [ 56,  93,  73],
#         [ 56,  93,  73],
#         [ 56,  93,  73]],
#
#        [[ 56,  95,  74],
#         [ 57,  96,  75],
#         [ 57,  96,  75],
#         ...,
#         [ 56,  93,  73],
#         [ 56,  93,  73],
#         [ 56,  93,  73]],
#
#        [[ 57,  96,  75],
#         [ 57,  96,  75],
#         [ 58,  97,  76],
#         ...,
#         [ 56,  93,  73],
#         [ 56,  93,  73],
#         [ 56,  93,  73]],
#
#        ...,
#
#        [[ 49,  84,  88],
#         [ 45,  82,  86],
#         [ 42,  80,  82],
#         ...,
#         [ 58,  98, 103],
#         [ 58,  99, 101],
#         [ 57,  98, 101]],
#
#        [[ 52,  83,  80],
#         [ 46,  79,  75],
#         [ 43,  76,  72],
#         ...,
#         [ 50,  92, 105],
#         [ 48,  91, 106],
#         [ 49,  92, 109]],
#
#        [[ 54,  85,  78],
#         [ 49,  80,  73],
#         [ 44,  77,  70],
# ...

# %%
np.shape(gray)
# Out:
# (194, 259)

# %%
import numpy as np

# %%
# Creating an image
blank=np.zeros((400,400),dtype='uint8')
cv.imshow('Blank Image',blank)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# ### Home Task
# #### Q. What is a Coordinate and how we access the co-ordinates

# %% [markdown]
# ## Practice

# %%
import cv2 as cv

# %%
pic=cv.imread(r'bird.webp')
cv.imshow('newfig',pic)
cv.waitKey(0)
# Out:
# -1

# %%
import matplotlib.pyplot as plt 
pic=cv.imread(r'bird.webp')
plt.imshow(pic)

# %%
img=cv.imread(r'bird.webp')
cv.imwrite(r'bird3.webp',img)
cv.imshow('window',img)
cv.waitKey(0)
# Out:
# -1

# %%
rotate=cv.rotate(img,cv.ROTATE_90_COUNTERCLOCKWISE) #rotation
scale=cv.resize(img,(500,500))
cv.imshow('windows',rotate)
cv.imshow('windows',scale)
cv.waitKey(0)
# Out:
# -1

# %%
rgb=cv.cvtColor(img,cv.COLOR_RGB2BGR)
grey=cv.cvtColor(img,cv.COLOR_RGB2GRAY)
cv.imshow('windows',rgb)
cv.imshow('window',grey)
cv.waitKey(0)
# Out:
# -1

# %%
import numpy as np
blank=np.zeros((400,400,3),dtype='uint8')
cv.imshow('Blank Image',blank)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
blank=np.ones((200,200,3),dtype='uint8')
cv.imshow('Blank Image',blank)
cv.waitKey(0)
# Out:
# -1

# %%
blank[:]=(255,0,0)
cv.imshow('windows',blank)
cv.waitKey(0)
# Out:
# -1

# %%
blank[10:100]=(0,255,0)
cv.imshow('windows',blank)
cv.waitKey(0)
# Out:
# -1

# %%
blank[40:150]=(0,0,255)
cv.imshow('windows',blank)
cv.waitKey(0)
# Out:
# -1

# %%
blank[100:150]=(0,200,255)
cv.imshow('windows',blank)
cv.waitKey(0)
# Out:
# -1

# %%
blank[40:100]=(255,200,255)
cv.imshow('windows',blank)
cv.waitKey(0)
# Out:
# -1

# %%
blank[140:200]=(150,200,255)
cv.imshow('windows',blank)
cv.waitKey(0)
# Out:
# -1

# %%
blank[200:250]=(0,255,255)
cv.imshow('windows',blank)
cv.waitKey(0)
# Out:
# -1

# %% [markdown]
# ## Coordinates

# %%
rect=cv.rectangle(blank,(0,0),(50,50),(0,255,0),thickness=cv.FILLED)
cv.imshow('pic',rect)
cv.waitKey(0)
# Out:
# -1

# %%
rect2=cv.rectangle(blank,(100,100),(200,200),(0,255,0),thickness=cv.FILLED)
cv.imshow('pic',rect2)
cv.waitKey(0)
# Out:
# -1

# %%
rect2=cv.rectangle(blank,(200,200),(300,300),(0,255,0),thickness=cv.FILLED)
cv.imshow('picture',rect2)
cv.waitKey(0)
# Out:
# -1

# %%
rect3=cv.rectangle(blank,(200,200),(300,300),(0,255,0),thickness=cv.FILLED)
cv.imshow('picture',rect3)
cv.waitKey(0)
# Out:
# -1

# %%
line=cv.line(blank,(10,10),(200,200),(0,0,255),1) #Line
line=cv.line(blank,(300,10),(10,10),(0,0,255),1) #Line
cv.imshow('line',line)
cv.waitKey(0)
# Out:
# -1

# %%
img=cv.imread('bird.webp')
circle=cv.circle(img,(100,100),50,(0,255,255),1)
cv.imshow('circle',circle)
cv.waitKey(0)
# Out:
# -1

# %%
text=cv.putText(img,'Gul Munir Hassan',(20,60),cv.FONT_HERSHEY_COMPLEX,1.5,(0,0,255))
cv.imshow('text',text)
cv.waitKey(0)
# Out:
# -1

# %%
text1=cv.putText(img,'BIG DATA',(20,60),cv.FONT_HERSHEY_COMPLEX_SMALL,1.5,(0,0,255))
cv.imshow('text',text1)
cv.waitKey(0)
# Out:
# -1

# %%
img=cv.imread('colorfull.jpg')

# %%
text1=cv.putText(img,'BIG DATA',(20,60),cv.FONT_HERSHEY_COMPLEX_SMALL,1.5,(0,0,255))
cv.imshow('text',text1)
cv.waitKey(0)
# Out:
# -1

# %%
blur=cv.blur(img,(20,20))
cv.imshow('Average Blur',blur)
cv.waitKey(0)
# Out:
# -1

# %%
gaussblur=cv.GaussianBlur(img,(5,5),0)
cv.imshow('Gaussian Blur',gaussblur)
cv.waitKey(0)
# Out:
# -1

# %% [markdown]
# ## Task
# - Task to make 2 Different Emojis and mention their Names

# %%
import numpy as np
import cv2 as cv
#image=np.zeros((400,1000,3),dtype='uint8')
#image[:400,:500]=(255,255,0)
#cv.imwrite('Emogie.jpg',image)
image=cv.imread('Emoji.jpg')
#image[:400,500:1000]=(0,255,255)
#cv.imwrite('Emogie.jpg',image)
#circle=cv.circle(image,(200,200),100,(0,0,255),2)
#cv.imwrite('Emogie.jpg',circle)
#circle=cv.circle(image,(750,200),100,(255,0,255),2)
#circle=cv.circle(image,(150,165),10,(0,0,255),2)
#circle=cv.circle(image,(240,165),10,(0,0,255),2)
#circle=cv.circle(image,(700,165),10,(255,0,255),2)
#circle=cv.circle(image,(795,165),10,(255,0,255),2)
#line=cv.line(image,(165,220),(230,220),(255,255,0),2)
#line=cv.line(image,(710,220),(780,230),(0,255,255),2)
#ellipse=cv.ellipse(image,(200,219),(50,50),0,0,180,(255,0,255),2)
#ellipse=cv.ellipse(image,(750,250),(50,50),0,180,360,(0,0,255),2)
#text=cv.putText(image,'Happy Face',(0,50),cv.FONT_HERSHEY_PLAIN,3,(0,0,0),2)
#text=cv.putText(image,'Sad Face',(600,50),cv.FONT_HERSHEY_PLAIN,3,(0,0,0),2)
#cv.imwrite('Emoji.jpg',text)
cv.imshow('Emoji World',image)
cv.waitKey(0)
# Out:
# -1

# %% [markdown]
# ## Blurr

# %%
import cv2 as cv
image=cv.imread('bird.webp')
blur=cv.blur(image,(3,3),0)
gaussian=cv.GaussianBlur(image,(3,3),0)
median=cv.medianBlur(image,3)
bilateral=cv.bilateralFilter(image,5,2,3)
cv.imshow('Original Image',image)
cv.imshow('Blurr',blur)
cv.imshow('Gaussian Blurr',gaussian)
cv.imshow('Median Blurr',median)
cv.imshow('Bilateral Filter',bilateral)
cv.waitKey(0)
# Out:
# -1

# %% [markdown]
# ## Edge Detection

# %%
#canny Detection
import cv2 as cv
image=cv.imread('ImageExplore.png')
can=cv.Canny(image,200,400)
sobel_xy=cv.Sobel(image,cv.CV_64F,1,1)
sobel_x=cv.Sobel(image,cv.CV_64F,1,0)
sobel_y=cv.Sobel(image,cv.CV_64F,0,1)
#can.shape
cv.imshow('Edge Detection by Canny',can)
cv.imshow('XY-Sobel Edge Detection',sobel_xy)
cv.imshow('X-Sobel Edge Detection',sobel_x)
cv.imshow('Y-Sobel Edge Detection',sobel_y)

cv.waitKey(0)
# Out:
# -1

# %% [markdown]
# #### Color Channel

# %%
import cv2 as cv
image=cv.imread('ImageExplore.png')
b,g,r=cv.split(image)
cv.imshow('green',g)
cv.imshow('blue',b)
cv.imshow('red',r)
cv.imshow('original',image)
merge=cv.merge([b,g,r])
cv.imshow('merge image',merge)
cv.waitKey(0)
# Out:
# -1

# %% [markdown]
# Contour Detection and Edge Detection
# HSV
# High Stauration value
# HSL
# Hue Saturation
# Lightness

# %%
import cv2 as cv

# %%
import cv2 as cv
image=cv.imread('bird.webp')
canny=cv.Canny(image,100,200)
Contours,Hierarchy=cv.findContours(canny,cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
h=cv.drawContours(image,Contours,-1,(0,255,255),)
cv.imshow('Contour Image',h)
cv.waitKey(0)
# Out:
# -1

# %% [markdown]
# Face Detection by using Contouring

# %%
import cv2 as cv
img=cv.imread('profile.jpg')
image=cv.resize(img,(500,500))
greyimage=cv.cvtColor(image,cv.COLOR_RGB2GRAY)
canny=cv.Canny(greyimage,200,50)
Contours,Hierarchy=cv.findContours(canny,cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
h=cv.drawContours(image,Contours,-1,(0,0,255),)
cv.imshow('Contour Image',h)
cv.waitKey(0)
# Out:
# -1

# %%
pip install matplotlib opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread("profile.jpg")

# %%
# convert to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# %%
# create a binary thresholded image
_, binary = cv2.threshold(gray, 190, 150, cv2.THRESH_BINARY_INV)
# show it
plt.imshow(binary, cmap="gray")
plt.show()

# %%
# find the contours from the thresholded image
contours, hierarchy = cv2.findContours(binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
# draw all contours
image = cv2.drawContours(image, contours, -1, (0, 255, 0), 2)

# %%
# show the image with the drawn contours
plt.imshow(image)
plt.show()

# %%
import numpy as np
import cv2 as cv
filename = 'profile.jpg'
img1 = cv.imread(filename)
img=cv.resize(img,(500,500))
cv.imwrite('Profile.jpg',img)
gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
gray = np.float32(gray)
dst = cv.cornerHarris(gray,2,3,0.04)
#result is dilated for marking the corners, not important
dst = cv.dilate(dst,None)
# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,255]
cv.imshow('dst',img)
if cv.waitKey(0) & 0xff == 27:
    cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv
filename = 'chessboard2.jpg'
img = cv.imread(filename)
gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
# find Harris corners
gray = np.float32(gray)
dst = cv.cornerHarris(gray,2,3,0.04)
dst = cv.dilate(dst,None)
ret, dst = cv.threshold(dst,0.01*dst.max(),255,0)
dst = np.uint8(dst)
# find centroids
ret, labels, stats, centroids = cv.connectedComponentsWithStats(dst)
# define the criteria to stop and refine the corners
criteria = (cv.TERM_CRITERIA_EPS + cv.TERM_CRITERIA_MAX_ITER, 100, 0.001)
corners = cv.cornerSubPix(gray,np.float32(centroids),(5,5),(-1,-1),criteria)
# Now draw them
res = np.hstack((centroids,corners))
res = np.int0(res)
img[res[:,1],res[:,0]]=[0,0,255]
img[res[:,3],res[:,2]] = [0,255,0]
cv.imwrite('subpixel5.png',img)

# %%
import cv2 as cv
img= cv.imread('profile.jpg')
img= cv.resize(img,(512,512),1)
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
thresh, binary = cv.threshold(gray, 200,100, cv.THRESH_BINARY)

Contours, Hierarchy= cv.findContours(binary,cv.RETR_EXTERNAL,cv.CHAIN_APPROX_NONE)
img= cv.drawContours(img,Contours,-1,(255,0,0),2)

cv.imshow('ok',img)
cv.waitKey(0)
# Out:
# -1
